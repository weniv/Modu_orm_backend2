# %% [markdown]
# # 판다스 세팅

# %%
# !pip install koreanize-matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
import koreanize_matplotlib

# %%
import numpy as np
import pandas as pd

# %%
print(np.__version__)
print(pd.__version__)
# Out:
# 1.25.2
# 2.0.3

# %%
# 간단한 데이터 생성
np_array = np.array([1,2,3,4,5]) # array는 파이썬의 리스트
print(np_array)
print(type(np_array))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
# pandas를 사용한 기초 구조 생성
# pandas series -> 1. 열로 정리가 된다. 2. index가 자동으로 생성된다.
pd_series = pd.Series(np_array)
print(pd_series)
print(type(pd_series)) # pandas의 series는 pandas.core.series.Series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# pandas 데이터 생성 DataFrame은 엑셀과 동일
# 딕셔너리 형태의 데이터를 DataFrame 메서드에 넣으면 엑셀파일과 같은 데이터 구조가 생성된다.
# type = class 'pandas.core.frame.DataFrame'
df = pd.DataFrame({
    '이름' : ['김진환','모두연'],
    '나이' : [20,21],
    '성별' : ['남','여'],
    '날짜' : ['20240101', '20240102']
})
print(df)
print(type(df)) # pandas의 dataframe은 pandas.core.frame.DataFrame
# Out:
#     이름  나이 성별        날짜
# 0  김진환  20  남  20240101
# 1  모두연  21  여  20240102
# <class 'pandas.core.frame.DataFrame'>

# %%
#1. DataFrame 생성 및 기본정보 확인

# 데이터 생성
data = {
    '이름' : ['김진환','모두연'],
    '나이' : [20,21],
    '성별' : ['남','여'],
    '날짜' : ['20240101', '20240102']
}

df = pd.DataFrame(data)
print(df)
print(df.info())
print(df.shape)

#2. 조건을 만족하는 데이터 필터링

modu_df = df[df['이름'] == '모두연']
print(modu_df)
# Out:
#     이름  나이 성별        날짜
# 0  김진환  20  남  20240101
# 1  모두연  21  여  20240102
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      2 non-null      object
#  1   나이      2 non-null      int64
#  2   성별      2 non-null      object
#  3   날짜      2 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 192.0+ bytes
# None
# (2, 4)
#     이름  나이 성별        날짜
# 1  모두연  21  여  20240102

# %%
import pandas as pd

# 시리즈 생성
names = pd.Series(['홍길동', '임꺽정', '이순신'])

# 시리즈 출력
print("시리즈 출력:")
print(names)

# 시리즈의 데이터 타입 확인
print("\\n시리즈의 데이터 타입:")
print(names.dtype)

# 시리즈의 인덱스 확인
print("\\n시리즈의 인덱스:")
print(names.index)
# Out:
# 시리즈 출력:
# 0    홍길동
# 1    임꺽정
# 2    이순신
# dtype: object
# \n시리즈의 데이터 타입:
# object
# \n시리즈의 인덱스:
# RangeIndex(start=0, stop=3, step=1)

# %%
# 사용자 정의 인덱스 설정
names_with_index = pd.Series(['홍길동', '임꺽정', '이순신'], index=['a', 'b', 'c'])

# 시리즈 출력
print("사용자 정의 인덱스를 가진 시리즈:")
print(names_with_index)

# 특정 인덱스를 사용하여 데이터 접근
print("\\n인덱스 'b'의 데이터:")
print(names_with_index['b'])

# 벡터화 연산 예시: 모든 이름에 '님'을 추가
print("\\n벡터화 연산 예시 (모든 이름에 '님' 추가):")
print(names_with_index + '님')
# Out:
# 사용자 정의 인덱스를 가진 시리즈:
# a    홍길동
# b    임꺽정
# c    이순신
# dtype: object
# \n인덱스 'b'의 데이터:
# 임꺽정
# \n벡터화 연산 예시 (모든 이름에 '님' 추가):
# a    홍길동님
# b    임꺽정님
# c    이순신님
# dtype: object

# %%
# 나이 데이터 시리즈 생성
ages = pd.Series([30, 35, 40], index=['홍길동', '임꺽정', '이순신'])

# 시리즈 출력
print("나이 데이터 시리즈:")
print(ages)

# 조건에 따른 데이터 필터링 (나이가 35 이상인 데이터)
print("\\n나이가 35 이상인 데이터:")
print(ages[ages >= 35])
# Out:
# 나이 데이터 시리즈:
# 홍길동    30
# 임꺽정    35
# 이순신    40
# dtype: int64
# \n나이가 35 이상인 데이터:
# 임꺽정    35
# 이순신    40
# dtype: int64

# %%
df.to_csv('example.csv', index=False)

# %%
df.to_excel('example.xlsx', index=False)

# %%
df.head()

# %%
df.describe()
# Out:
#               나이
# count   2.000000
# mean   20.500000
# std     0.707107
# min    20.000000
# 25%    20.250000
# 50%    20.500000
# 75%    20.750000
# max    21.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_31['나이'].plot(kind='hist', bins=20, title='나이')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_32['나이'].plot(kind='line', figsize=(8, 4), title='나이')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Pandas DataFrame 예시
import pandas as pd
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'Berlin']
})

# 각 속성 호출
print("Shape:", df.shape)
print("Data Types:\n", df.dtypes)
print("Index:", df.index)
print("Columns:", df.columns)
# Out:
# Shape: (3, 3)
# Data Types:
#  Name    object
# Age      int64
# City    object
# dtype: object
# Index: RangeIndex(start=0, stop=3, step=1)
# Columns: Index(['Name', 'Age', 'City'], dtype='object')

# %%
import pandas as pd

# 예시 데이터프레임 생성
data = {
    'Name': ['Alice', 'Bob'],  # 문자열 타입
    'Age': ['25', '30'],       # 숫자 데이터를 문자열로 표현
    'Member': ['True', 'False'],  # 불린 데이터를 문자열로 표현
    'Join Date': ['2021-01-01', '2021-07-01']  # 날짜 데이터를 문자열로 표현
}

df = pd.DataFrame(data)

# 결과 출력
print(df)
print(df.dtypes)# 결과 출력
# Out:
#     Name Age Member   Join Date
# 0  Alice  25   True  2021-01-01
# 1    Bob  30  False  2021-07-01
# Name         object
# Age          object
# Member       object
# Join Date    object
# dtype: object

# %%
# 데이터 타입 변환
df['Age'] = df['Age'].astype(int)  # 'Age' 열을 정수형으로 변환
df['Member'] = df['Member'].astype(bool)  # 'Member' 열을 불린형으로 변환
df['Join Date'] = pd.to_datetime(df['Join Date'])  # 'Join Date' 열을 datetime으로 변환

# 결과 출력
print(df)
print(df.dtypes)
# Out:
#     Name  Age  Member  Join Date
# 0  Alice   25    True 2021-01-01
# 1    Bob   30    True 2021-07-01
# Name                 object
# Age                   int64
# Member                 bool
# Join Date    datetime64[ns]
# dtype: object

# %%
import pandas as pd
import numpy as np

# 예시 데이터프레임 생성
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'Berlin']
}
df = pd.DataFrame(data)

# 단일 열 선택 -> 결과는 Series
age_series = df['Age']
print(type(age_series))

# 다중 열 선택 -> 결과는 DataFrame
subset_df = df[['Name', 'City']]
print(type(subset_df))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# 다중 열 선택 -> 결과는 DataFrame
subset_df = df['Name', 'City']
print(type(subset_df))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'City')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-e9297a9e6313> in <cell line: 2>()
#       1 # 다중 열 선택 -> 결과는 DataFrame
# ----> 2 subset_df = df['Name', 'City']
#       3 print(type(subset_df))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('Name', 'City')

# %%
# loc 사용 예시
print(df.loc[:, 'Age'])

# iloc 사용 예시
print(df.iloc[:, 1])

# 결측치 추가
df.loc[1, 'Age'] = np.nan

# 결측치 확인
print(df['Age'].isnull())
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64
# 0    False
# 1     True
# 2    False
# Name: Age, dtype: bool

# %%
import pandas as pd

# Series 생성
data = pd.Series([10, 20, 20, 30, 40])

# sum(), mean(), value_counts() 사용 예시
print("Sum:", data.sum())           # 합계
print("Mean:", data.mean())         # 평균
print("Value Counts:\n", data.value_counts())  # 빈도 계산
# Out:
# Sum: 120
# Mean: 24.0
# Value Counts:
#  20    2
# 10    1
# 30    1
# 40    1
# Name: count, dtype: int64

# %%
import pandas as pd

# Series 생성
data = pd.Series([10, 15, 20, 25, 30])

# 다양한 메서드 활용
print("Minimum:", data.min())          # 최소값
print("Maximum:", data.max())          # 최대값
print("Standard Deviation:", data.std())  # 표준편차
print("Variance:", data.var())          # 분산
print("Number of Unique Values:", data.nunique())  # 고유값 개수

# 데이터프레임 요약
df = pd.DataFrame({
    'Age': [25, 30, 35, 40, 45],
    'Salary': [50000, 55000, 60000, 65000, 70000]
})
print("\nDataFrame Summary:\n", df.describe())
print("\nDataFrame Info:")
df.info()
# Out:
# Minimum: 10
# Maximum: 30
# Standard Deviation: 7.905694150420948
# Variance: 62.5
# Number of Unique Values: 5
#
# DataFrame Summary:
#               Age       Salary
# count   5.000000      5.00000
# mean   35.000000  60000.00000
# std     7.905694   7905.69415
# min    25.000000  50000.00000
# 25%    30.000000  55000.00000
# 50%    35.000000  60000.00000
# 75%    40.000000  65000.00000
# max    45.000000  70000.00000
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     5 non-null      int64
#  1   Salary  5 non-null      int64
# dtypes: int64(2)
# memory usage: 208.0 bytes

# %%
import pandas as pd

# Series 생성
numbers = pd.Series([10, 20, 30, 40, 50])

# 기본 연산자 사용
print("Addition:", numbers + 10)         # 각 요소에 10 더하기
print("Multiplication:", numbers * 2)     # 각 요소에 2 곱하기

# 조건부 연산 및 불린 연산
print("Greater than 30:\n", numbers > 30)  # 30보다 큰 요소 찾기
print("Filtered Series:\n", numbers[numbers > 30])  # 조건을 만족하는 요소만 필터링
# Out:
# Addition: 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64
# Multiplication: 0     20
# 1     40
# 2     60
# 3     80
# 4    100
# dtype: int64
# Greater than 30:
#  0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool
# Filtered Series:
#  3    40
# 4    50
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})

# 열 이름 변경
df = df.rename(columns={'A': 'X', 'B': 'Y', 'C': 'Z'})
print(df)
# Out:
#    X  Y  Z
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
})

# 'Salary'라는 새 열 추가
df['Salary'] = [50000, 60000, 70000]
print(df)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
# 'Age' 열 삭제
df = df.drop('Age', axis=1) # 1은 열
print(df)
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   70000

# %% [markdown]
# #loc와 iloc

# %%
# 데이터 불러오기

# 구분자 csv = , 기존의 열의 이름을 사용하지 않겠다.
df = pd.read_csv('nasa_http_sample.csv', sep = ',', header = None,
                 names = ['ip', 'dummy1', 'dummy2', 'timesteamp', 'request', 'status', 'size'])
print(df)
# Out:
#                       ip    dummy1  dummy2                  timesteamp  \
# 0                   Host  Identity  UserID                    DateTime
# 1           199.72.81.55         -       -  01/Jul/1995:00:00:01 -0400
# 2   unicomp6.unicomp.net         -       -  01/Jul/1995:00:00:06 -0400
# 3         199.120.110.21         -       -  01/Jul/1995:00:00:09 -0400
# 4     burger.letters.com         -       -  01/Jul/1995:00:00:11 -0400
# 5         199.120.110.21         -       -  01/Jul/1995:00:00:11 -0400
# 6     burger.letters.com         -       -  01/Jul/1995:00:00:12 -0400
# 7     burger.letters.com         -       -  01/Jul/1995:00:00:12 -0400
# 8        205.212.115.106         -       -  01/Jul/1995:00:00:12 -0400
# 9            d104.aa.net         -       -  01/Jul/1995:00:00:13 -0400
# 10        129.94.144.152         -       -  01/Jul/1995:00:00:13 -0400
#
#                                               request  status  size
# 0                                             Request  Status  Size
# 1                       GET /history/apollo/ HTTP/1.0     200  6245
# 2                    GET /shuttle/countdown/ HTTP/1.0     200  3985
# 3   GET /shuttle/missions/sts-73/mission-sts-73.ht...     200  4085
# 4        GET /shuttle/countdown/liftoff.html HTTP/1.0     304     0
# 5   GET /shuttle/missions/sts-73/sts-73-patch-smal...     200  4179
# 6             GET /images/NASA-logosmall.gif HTTP/1.0     304     0
# 7   GET /shuttle/countdown/video/livevideo.gif HTT...     200     0
# 8      GET /shuttle/countdown/countdown.html HTTP/1.0     200  3985
# 9                    GET /shuttle/countdown/ HTTP/1.0     200  3985
# 10                                     GET / HTTP/1.0     200  7074

# %%
df = df.drop(['dummy1', 'dummy2'], axis = 1)
print(df)
# Out:
#                       ip                  timesteamp  \
# 0                   Host                    DateTime
# 1           199.72.81.55  01/Jul/1995:00:00:01 -0400
# 2   unicomp6.unicomp.net  01/Jul/1995:00:00:06 -0400
# 3         199.120.110.21  01/Jul/1995:00:00:09 -0400
# 4     burger.letters.com  01/Jul/1995:00:00:11 -0400
# 5         199.120.110.21  01/Jul/1995:00:00:11 -0400
# 6     burger.letters.com  01/Jul/1995:00:00:12 -0400
# 7     burger.letters.com  01/Jul/1995:00:00:12 -0400
# 8        205.212.115.106  01/Jul/1995:00:00:12 -0400
# 9            d104.aa.net  01/Jul/1995:00:00:13 -0400
# 10        129.94.144.152  01/Jul/1995:00:00:13 -0400
#
#                                               request  status  size
# 0                                             Request  Status  Size
# 1                       GET /history/apollo/ HTTP/1.0     200  6245
# 2                    GET /shuttle/countdown/ HTTP/1.0     200  3985
# 3   GET /shuttle/missions/sts-73/mission-sts-73.ht...     200  4085
# 4        GET /shuttle/countdown/liftoff.html HTTP/1.0     304     0
# 5   GET /shuttle/missions/sts-73/sts-73-patch-smal...     200  4179
# 6             GET /images/NASA-logosmall.gif HTTP/1.0     304     0
# 7   GET /shuttle/countdown/video/livevideo.gif HTT...     200     0
# 8      GET /shuttle/countdown/countdown.html HTTP/1.0     200  3985
# 9                    GET /shuttle/countdown/ HTTP/1.0     200  3985
# 10                                     GET / HTTP/1.0     200  7074

# %%
df = df.drop(index=0)
print(df)
# Out:
#                       ip                  timesteamp  \
# 1           199.72.81.55  01/Jul/1995:00:00:01 -0400
# 2   unicomp6.unicomp.net  01/Jul/1995:00:00:06 -0400
# 3         199.120.110.21  01/Jul/1995:00:00:09 -0400
# 4     burger.letters.com  01/Jul/1995:00:00:11 -0400
# 5         199.120.110.21  01/Jul/1995:00:00:11 -0400
# 6     burger.letters.com  01/Jul/1995:00:00:12 -0400
# 7     burger.letters.com  01/Jul/1995:00:00:12 -0400
# 8        205.212.115.106  01/Jul/1995:00:00:12 -0400
# 9            d104.aa.net  01/Jul/1995:00:00:13 -0400
# 10        129.94.144.152  01/Jul/1995:00:00:13 -0400
#
#                                               request status  size
# 1                       GET /history/apollo/ HTTP/1.0    200  6245
# 2                    GET /shuttle/countdown/ HTTP/1.0    200  3985
# 3   GET /shuttle/missions/sts-73/mission-sts-73.ht...    200  4085
# 4        GET /shuttle/countdown/liftoff.html HTTP/1.0    304     0
# 5   GET /shuttle/missions/sts-73/sts-73-patch-smal...    200  4179
# 6             GET /images/NASA-logosmall.gif HTTP/1.0    304     0
# 7   GET /shuttle/countdown/video/livevideo.gif HTT...    200     0
# 8      GET /shuttle/countdown/countdown.html HTTP/1.0    200  3985
# 9                    GET /shuttle/countdown/ HTTP/1.0    200  3985
# 10                                     GET / HTTP/1.0    200  7074

# %%
# 데이터 미리보기
df.head()
# Out:
#                      ip                  timesteamp  \
# 1          199.72.81.55  01/Jul/1995:00:00:01 -0400
# 2  unicomp6.unicomp.net  01/Jul/1995:00:00:06 -0400
# 3        199.120.110.21  01/Jul/1995:00:00:09 -0400
# 4    burger.letters.com  01/Jul/1995:00:00:11 -0400
# 5        199.120.110.21  01/Jul/1995:00:00:11 -0400
#
#                                              request status  size
# 1                      GET /history/apollo/ HTTP/1.0    200  6245
# 2                   GET /shuttle/countdown/ HTTP/1.0    200  3985
# 3  GET /shuttle/missions/sts-73/mission-sts-73.ht...    200  4085
# 4       GET /shuttle/countdown/liftoff.html HTTP/1.0    304     0
# 5  GET /shuttle/missions/sts-73/sts-73-patch-smal...    200  4179

# %%
# loc 예제 1

# 열을 불러온다. df.loc[행, 열]
print(df.loc[:, 'ip'])
# Out:
# 1             199.72.81.55
# 2     unicomp6.unicomp.net
# 3           199.120.110.21
# 4       burger.letters.com
# 5           199.120.110.21
# 6       burger.letters.com
# 7       burger.letters.com
# 8          205.212.115.106
# 9              d104.aa.net
# 10          129.94.144.152
# Name: ip, dtype: object

# %%
print(df.loc[df['status'] == '200'])
# Out:
#                       ip                  timesteamp  \
# 1           199.72.81.55  01/Jul/1995:00:00:01 -0400
# 2   unicomp6.unicomp.net  01/Jul/1995:00:00:06 -0400
# 3         199.120.110.21  01/Jul/1995:00:00:09 -0400
# 5         199.120.110.21  01/Jul/1995:00:00:11 -0400
# 7     burger.letters.com  01/Jul/1995:00:00:12 -0400
# 8        205.212.115.106  01/Jul/1995:00:00:12 -0400
# 9            d104.aa.net  01/Jul/1995:00:00:13 -0400
# 10        129.94.144.152  01/Jul/1995:00:00:13 -0400
#
#                                               request status  size
# 1                       GET /history/apollo/ HTTP/1.0    200  6245
# 2                    GET /shuttle/countdown/ HTTP/1.0    200  3985
# 3   GET /shuttle/missions/sts-73/mission-sts-73.ht...    200  4085
# 5   GET /shuttle/missions/sts-73/sts-73-patch-smal...    200  4179
# 7   GET /shuttle/countdown/video/livevideo.gif HTT...    200     0
# 8      GET /shuttle/countdown/countdown.html HTTP/1.0    200  3985
# 9                    GET /shuttle/countdown/ HTTP/1.0    200  3985
# 10                                     GET / HTTP/1.0    200  7074

# %%
print(df.loc[df['ip'] == 'burger.letters.com'])
# Out:
#                    ip                  timesteamp  \
# 4  burger.letters.com  01/Jul/1995:00:00:11 -0400
# 6  burger.letters.com  01/Jul/1995:00:00:12 -0400
# 7  burger.letters.com  01/Jul/1995:00:00:12 -0400
#
#                                              request status size
# 4       GET /shuttle/countdown/liftoff.html HTTP/1.0    304    0
# 6            GET /images/NASA-logosmall.gif HTTP/1.0    304    0
# 7  GET /shuttle/countdown/video/livevideo.gif HTT...    200    0

# %%
## 단일 열 선택 / 여러 열 선택
print(df.loc[:, 'ip'])
# Out:
# 1             199.72.81.55
# 2     unicomp6.unicomp.net
# 3           199.120.110.21
# 4       burger.letters.com
# 5           199.120.110.21
# 6       burger.letters.com
# 7       burger.letters.com
# 8          205.212.115.106
# 9              d104.aa.net
# 10          129.94.144.152
# Name: ip, dtype: object

# %%
print(df.loc[:, ['ip', 'status']])
# Out:
#                       ip status
# 1           199.72.81.55    200
# 2   unicomp6.unicomp.net    200
# 3         199.120.110.21    200
# 4     burger.letters.com    304
# 5         199.120.110.21    200
# 6     burger.letters.com    304
# 7     burger.letters.com    200
# 8        205.212.115.106    200
# 9            d104.aa.net    200
# 10        129.94.144.152    200

# %%
# 특정 열에 있는 특정 행을 추출!
# start stop step
print(df.loc[1:3:2 , 'ip'])
# Out:
# 1      199.72.81.55
# 3    199.120.110.21
# Name: ip, dtype: object

# %%
#df.loc[행에 대한 조건, 열에 대한 조건]
df.loc[df['ip'] == '205.212.115.106', 'request']
# Out:
# 8    GET /shuttle/countdown/countdown.html HTTP/1.0
# Name: request, dtype: object

# %%
df.loc[df['status'] == '404', ['ip', 'timesteamp']]
# Out:
# Empty DataFrame
# Columns: [ip, timesteamp]
# Index: []

# %%
실습을 하면서 여려운점 물어보기
실습 시간에 대한 부분
실습 내용에 대한 부분
# Out:
#   File "<ipython-input-61-df4485b63284>", line 1
#     실습을 하면서 여려운점 물어보기
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# 주문 데이터를 데이터프레임으로 생성
order_data = {
    'order_id': [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010],
    'customer_id': ['C001', 'C002', 'C003', 'C001', 'C004', 'C002', 'C005', 'C003', 'C001', 'C004'],
    'order_date': ['2023-07-01', '2023-07-01', '2023-07-02', '2023-07-02', '2023-07-03', '2023-07-03',
                   '2023-07-04', '2023-07-04', '2023-07-05', '2023-07-05'],
    'product_category': ['Electronics', 'Books', 'Clothing', 'Electronics', 'Books', 'Clothing',
                         'Electronics', 'Books', 'Clothing', 'Electronics'],
    'quantity': [2, 3, 1, 1, 2, 4, 1, 2, 3, 1],
    'price': [500, 20, 50, 800, 15, 30, 600, 25, 40, 700],
    'total': [1000, 60, 50, 800, 30, 120, 600, 50, 120, 700]
}

df_orders = pd.DataFrame(order_data)

# CSV 파일로 저장
csv_file_path_orders = "online_shopping_orders_new.csv"
df_orders.to_csv(csv_file_path_orders, index=False)

# %%
df_orders.groupby('customer_id').agg({
    'total' : ['sum','mean'],
})
# Out:
#             total
#               sum   mean
# customer_id
# C001         1920  640.0
# C002          180   90.0
# C003          100   50.0
# C004          730  365.0
# C005          600  600.0

# %%
# 그룹화 집계
daily_sales = df_orders.groupby('product_category')['total'].sum()
print(daily_sales)
# Out:
# product_category
# Books           140
# Clothing        290
# Electronics    3100
# Name: total, dtype: int64

# %%
daily_sales_new = df_orders.groupby('product_category').agg({
    'quantity' : ['sum'],
})
print(daily_sales_new)
# Out:
#                  quantity total
#                       sum   sum
# product_category
# Books                   7   140
# Clothing                8   290
# Electronics             5  3100

# %%
daily_sales_new2 = df_orders.groupby(['order_date', 'product_category'])['total'].sum().unstack()
print(daily_sales_new2)
# Out:
# product_category  Books  Clothing  Electronics
# order_date
# 2023-07-01         60.0       NaN       1000.0
# 2023-07-02          NaN      50.0        800.0
# 2023-07-03         30.0     120.0          NaN
# 2023-07-04         50.0       NaN        600.0
# 2023-07-05          NaN     120.0        700.0

# %%
1. group by에 가장 기본 한가지 구분/ 한가지 열을 가지고, 한가지 값을 활용한 집계
2. group by에 가장 기본 한가지 구분/ 한가지 열을 가지고, 두가지 값을 활용한 집계
3. group by에 가장 기본 한가지 구분/ 두가지 열을 가지고, 한가지 값을 활용한 집계

# %%
# 1. B / D 랑 key가 겹칩니다.! -> 두 테이블에서 내가 어떠한 기준으로 데이터를 결합할것인가?
# -> 결과에 대해서 생각을 할수있으면 더 좋아요.


df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                    'value': [1, 2, 3, 4]})

df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
                    'value': [5, 6, 7, 8]})

# inner = 서로 같은것만!
# left = 서로 같은것 + 왼쪽 테이블에 있는 key까지
# right = 서로 같은것 + 오른쪽 테이블에 있는 key까지
                     #왼쪽 #오른쪽
merged_df = pd.merge(df1 , df2, on='key', how='right')
print(merged_df)
# Out:
#   key  value_x  value_y
# 0   B      2.0        5
# 1   D      4.0        6
# 2   E      NaN        7
# 3   F      NaN        8

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7']})

concatenated_df = pd.concat([df1, df2], axis=0)
print(concatenated_df)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  A4  B4
# 1  A5  B5
# 2  A6  B6
# 3  A7  B7

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7']})

concatenated_df = pd.concat([df1, df2], axis=1)
print(concatenated_df)
# Out:
#     A   B   A   B
# 0  A0  B0  A4  B4
# 1  A1  B1  A5  B5
# 2  A2  B2  A6  B6
# 3  A3  B3  A7  B7
